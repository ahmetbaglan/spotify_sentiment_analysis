# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ### Spotify Happiness / Popularity Analysis

# %% [markdown]
# Hi people of Earth! Recently I have seen a title in a famous Turkish blog "Eksi Sozluk". The title was asking about the most heartbreaking / sorrowful song of one of my favorite artists Sezen Aksu. So I decided to investigate this over :)

# %% [markdown]
# I dunno about you guys but I tend to listen songs depending on my mood, sometimes I just listen depressive ones and sometimes just something to fire me up. So I asked myself how can I come up with the happiest or saddest song of given artist. And apparently Spotify has already got the answers so I just easily decided to reveal them.
#
# Hope you like it :)
#
# **Note:** If you are interested, I suggest checking out the code while reading but just click on the "Toggle Code" button if you don't wanna see. And frankly I wouldn't mind having a couple of github stars if you have an account :) ([Github Page](https://github.com/ahmetbaglan/spotify_sentiment_analysis)
# )

# %% [markdown]
# So let's start with importing some libraries

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pandas as pd

# %%
cid = ''
csec = ''
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=csec)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace=False

# %% [markdown]
# Spotify has API, they are providing a couple of things for each song. For example, they have scored features below for each song. (For getting your own credentials visit https://developer.spotify.com/dashboard/applications and create an application)
#
# **acousticness:** A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#
# **danceability:** Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# **energy:** Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#
# **loudness:**The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#
# **valence:**A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# **tempo:** The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# https://developer.spotify.com/documentation/web-api/reference/tracks/get-audio-features/

# %% [markdown]
# Unfortunately I have little understanding of music theory so in this analysis I will mostly see around how happy a song is (so valence feature)

# %%
## Let's create a function which grabs the song and its features

def getSongsDf(artist_name): # A function that get's first 50 (max given by api) songs by the artist. Input: the name of the artist
    featuresToGrab = ["name", "happiness", "danceability", "energy", "tempo", "loudness", "acousticness"]
    results = sp.search(q=artist_name, limit=50) # Query 
    tids = []
    for i, t in enumerate(results['tracks']['items']):
        tids.append(t['uri'])
    features = sp.audio_features(tids)
    songs  = pd.DataFrame(features)
    songs['name'] = [d['name'] for d in results['tracks']['items']]
    songs['duration_ms'] = [d['duration_ms'] for d in results['tracks']['items']]
    songs['artist_name'] = artist_name
    songs['happiness'] = songs['valence']
    songs.index = [artist_name for i in range(len(songs))]
    return songs[featuresToGrab]

# %% [markdown]
# So let's have a glance at most popular 50 songs by Sezen Aksu and their features. If you wanna duplicate the work for another artist just change my_artistvariable and rerun the notebook.

# %%
my_artist = 'Sezen Aksu'

sezenDf = getSongsDf(my_artist)
sezenDf
# Out:
#                                                     name  happiness  \
# Sezen Aksu                                     Manifesto      0.746
# Sezen Aksu  Gelsin Hayat Bildiği Gibi (feat. Sezen Aksu)      0.400
# Sezen Aksu                                     Vazgeçtim      0.188
# Sezen Aksu                          İhanetten Geri Kalan      0.403
# Sezen Aksu                                  Her Şeyi Yak      0.454
# Sezen Aksu                                           Vay      0.440
# Sezen Aksu                              Seni Kimler Aldı      0.163
# Sezen Aksu                                  Kaçın Kurası      0.808
# Sezen Aksu                   Ceylan - Kıvanch K Versiyon      0.470
# Sezen Aksu                                       Kutlama      0.754
# Sezen Aksu                                  Canımsın Sen      0.477
# Sezen Aksu                                   Tükeneceğiz      0.496
# Sezen Aksu                                    Biliyorsun      0.376
# Sezen Aksu                                   Seni Yerler      0.762
# Sezen Aksu                                        Git...      0.429
# Sezen Aksu                                       Küçüğüm      0.281
# Sezen Aksu                                 Şanıma İnanma      0.828
# Sezen Aksu                                       Tutuklu      0.537
# Sezen Aksu                                           Köz      0.458
# Sezen Aksu                               Unuttun mu Beni      0.723
# Sezen Aksu                          Haydi Gel Benimle Ol      0.520
# Sezen Aksu                               Kaybolan Yıllar      0.599
# Sezen Aksu                                      The Cure      0.313
# Sezen Aksu                             Ben Kedim Yatağım      0.322
# Sezen Aksu                                      Geri Dön      0.318
# Sezen Aksu                     Ne Kavgam Bitti Ne Sevdam      0.955
# Sezen Aksu                               Aşktan Ne Haber      0.629
# Sezen Aksu                                Seni İstiyorum      0.504
# Sezen Aksu                              Onu Alma Beni Al      0.852
# Sezen Aksu                                        Rakkas      0.767
# Sezen Aksu                                    Sen Ağlama      0.351
# Sezen Aksu                                 Masum Değiliz      0.239
# Sezen Aksu                                       Belalım      0.489
# Sezen Aksu                                  Keskin Bıçak      0.209
# Sezen Aksu                                 Çocuklar Gibi      0.352
# Sezen Aksu                       İstanbul İstanbul Olalı      0.359
# Sezen Aksu                                Güllerim Soldu      0.482
# Sezen Aksu                                         Geçer      0.214
# Sezen Aksu                                  Kusura Bakma      0.695
# Sezen Aksu                          Gitme Kal Bu Şehirde      0.446
# Sezen Aksu                                       Gülümse      0.106
# Sezen Aksu                                     İki Gözüm      0.463
# Sezen Aksu                                   Sarı Odalar      0.604
# Sezen Aksu                                     Gidiyorum      0.389
# Sezen Aksu                                 İkili Delilik      0.646
# Sezen Aksu                                        Firuze      0.528
# Sezen Aksu                              İzmir'in Kızları      0.744
# Sezen Aksu                           Kalbim Ege'de Kaldı      0.291
# Sezen Aksu                                  Sebahat Abla      0.918
# Sezen Aksu                          Kaç Yıl Geçti Aradan      0.643
#
#             danceability  energy    tempo  loudness  acousticness
# Sezen Aksu         0.743   0.798   95.013    -6.383       0.11600
# Sezen Aksu         0.769   0.621   93.972    -8.958       0.04110
# Sezen Aksu         0.480   0.217  140.601   -11.520       0.78400
# Sezen Aksu         0.485   0.730  174.015    -7.960       0.41900
# Sezen Aksu         0.570   0.366  106.900    -8.898       0.82400
# Sezen Aksu         0.404   0.427  120.172    -9.561       0.65900
# Sezen Aksu         0.272   0.365   92.035    -8.257       0.77400
# Sezen Aksu         0.609   0.731  158.284    -6.495       0.45500
# Sezen Aksu         0.744   0.556  108.012    -8.997       0.24700
# Sezen Aksu         0.632   0.377  114.148    -7.148       0.83700
# Sezen Aksu         0.621   0.878  126.027    -7.567       0.09670
# Sezen Aksu         0.395   0.675  177.053    -5.881       0.64900
# Sezen Aksu         0.446   0.546  125.961    -7.022       0.46600
# Sezen Aksu         0.752   0.814  119.026    -6.787       0.03150
# Sezen Aksu         0.325   0.557   69.835    -8.974       0.85000
# Sezen Aksu         0.427   0.191  140.666   -13.934       0.83400
# Sezen Aksu         0.709   0.800   95.993    -6.198       0.28800
# Sezen Aksu         0.753   0.561  132.055    -6.856       0.31000
# Sezen Aksu         0.337   0.476  108.597    -8.282       0.86900
# Sezen Aksu         0.662   0.784   98.005    -5.193       0.11800
# Sezen Aksu         0.641   0.795  119.750    -6.605       0.60900
# Sezen Aksu         0.304   0.659  113.021    -6.091       0.02860
# Sezen Aksu         0.372   0.597   78.986    -7.771       0.23300
# Sezen Aksu         0.334   0.344  135.056    -9.113       0.79800
# Sezen Aksu         0.424   0.489  136.254    -7.110       0.76800
# Sezen Aksu         0.624   0.849   89.745    -8.060       0.10100
# Sezen Aksu         0.745   0.934  119.985    -6.570       0.00212
# Sezen Aksu         0.726   0.895  120.926    -6.064       0.65300
# Sezen Aksu         0.741   0.718   96.069    -6.429       0.56200
# Sezen Aksu         0.754   0.854  116.031    -6.326       0.72300
# Sezen Aksu         0.390   0.558   79.559    -8.502       0.47000
# Sezen Aksu         0.634   0.131  114.950   -18.299       0.32800
# Sezen Aksu         0.335   0.420  167.912   -14.126       0.64800
# Sezen Aksu         0.362   0.454   94.108    -8.606       0.70700
# Sezen Aksu         0.409   0.302  106.960    -8.150       0.68500
# Sezen Aksu         0.465   0.470  143.676   -12.900       0.59800
# Sezen Aksu         0.547   0.751   92.721    -7.578       0.28300
# Sezen Aksu         0.395   0.543   80.871    -6.227       0.53700
# Sezen Aksu         0.654   0.533  127.490    -9.426       0.53200
# Sezen Aksu         0.435   0.788   95.602    -2.735       0.39500
# Sezen Aksu         0.427   0.268   96.814    -8.912       0.71000
# Sezen Aksu         0.360   0.478  101.121    -6.313       0.85900
# Sezen Aksu         0.653   0.815   89.985    -5.755       0.05920
# Sezen Aksu         0.395   0.327  110.352   -12.927       0.66100
# Sezen Aksu         0.708   0.666  134.963    -6.599       0.46000
# Sezen Aksu         0.339   0.781   79.270    -5.469       0.65300
# Sezen Aksu         0.610   0.616  144.926    -5.789       0.58300
# Sezen Aksu         0.445   0.121  162.926   -18.745       0.53900
# Sezen Aksu         0.647   0.682  109.985    -7.036       0.47400
# Sezen Aksu         0.385   0.755  120.154    -5.931       0.48500

# %% [markdown]
# But which one is the most sorrowfull? Let's see!

# %%
sezenDf.sort_values("happiness")
# Out:
#                                                     name  happiness  \
# Sezen Aksu                                       Gülümse      0.106
# Sezen Aksu                              Seni Kimler Aldı      0.163
# Sezen Aksu                                     Vazgeçtim      0.188
# Sezen Aksu                                  Keskin Bıçak      0.209
# Sezen Aksu                                         Geçer      0.214
# Sezen Aksu                                 Masum Değiliz      0.239
# Sezen Aksu                                       Küçüğüm      0.281
# Sezen Aksu                           Kalbim Ege'de Kaldı      0.291
# Sezen Aksu                                      The Cure      0.313
# Sezen Aksu                                      Geri Dön      0.318
# Sezen Aksu                             Ben Kedim Yatağım      0.322
# Sezen Aksu                                    Sen Ağlama      0.351
# Sezen Aksu                                 Çocuklar Gibi      0.352
# Sezen Aksu                       İstanbul İstanbul Olalı      0.359
# Sezen Aksu                                    Biliyorsun      0.376
# Sezen Aksu                                     Gidiyorum      0.389
# Sezen Aksu  Gelsin Hayat Bildiği Gibi (feat. Sezen Aksu)      0.400
# Sezen Aksu                          İhanetten Geri Kalan      0.403
# Sezen Aksu                                        Git...      0.429
# Sezen Aksu                                           Vay      0.440
# Sezen Aksu                          Gitme Kal Bu Şehirde      0.446
# Sezen Aksu                                  Her Şeyi Yak      0.454
# Sezen Aksu                                           Köz      0.458
# Sezen Aksu                                     İki Gözüm      0.463
# Sezen Aksu                   Ceylan - Kıvanch K Versiyon      0.470
# Sezen Aksu                                  Canımsın Sen      0.477
# Sezen Aksu                                Güllerim Soldu      0.482
# Sezen Aksu                                       Belalım      0.489
# Sezen Aksu                                   Tükeneceğiz      0.496
# Sezen Aksu                                Seni İstiyorum      0.504
# Sezen Aksu                          Haydi Gel Benimle Ol      0.520
# Sezen Aksu                                        Firuze      0.528
# Sezen Aksu                                       Tutuklu      0.537
# Sezen Aksu                               Kaybolan Yıllar      0.599
# Sezen Aksu                                   Sarı Odalar      0.604
# Sezen Aksu                               Aşktan Ne Haber      0.629
# Sezen Aksu                          Kaç Yıl Geçti Aradan      0.643
# Sezen Aksu                                 İkili Delilik      0.646
# Sezen Aksu                                  Kusura Bakma      0.695
# Sezen Aksu                               Unuttun mu Beni      0.723
# Sezen Aksu                              İzmir'in Kızları      0.744
# Sezen Aksu                                     Manifesto      0.746
# Sezen Aksu                                       Kutlama      0.754
# Sezen Aksu                                   Seni Yerler      0.762
# Sezen Aksu                                        Rakkas      0.767
# Sezen Aksu                                  Kaçın Kurası      0.808
# Sezen Aksu                                 Şanıma İnanma      0.828
# Sezen Aksu                              Onu Alma Beni Al      0.852
# Sezen Aksu                                  Sebahat Abla      0.918
# Sezen Aksu                     Ne Kavgam Bitti Ne Sevdam      0.955
#
#             danceability  energy    tempo  loudness  acousticness
# Sezen Aksu         0.427   0.268   96.814    -8.912       0.71000
# Sezen Aksu         0.272   0.365   92.035    -8.257       0.77400
# Sezen Aksu         0.480   0.217  140.601   -11.520       0.78400
# Sezen Aksu         0.362   0.454   94.108    -8.606       0.70700
# Sezen Aksu         0.395   0.543   80.871    -6.227       0.53700
# Sezen Aksu         0.634   0.131  114.950   -18.299       0.32800
# Sezen Aksu         0.427   0.191  140.666   -13.934       0.83400
# Sezen Aksu         0.445   0.121  162.926   -18.745       0.53900
# Sezen Aksu         0.372   0.597   78.986    -7.771       0.23300
# Sezen Aksu         0.424   0.489  136.254    -7.110       0.76800
# Sezen Aksu         0.334   0.344  135.056    -9.113       0.79800
# Sezen Aksu         0.390   0.558   79.559    -8.502       0.47000
# Sezen Aksu         0.409   0.302  106.960    -8.150       0.68500
# Sezen Aksu         0.465   0.470  143.676   -12.900       0.59800
# Sezen Aksu         0.446   0.546  125.961    -7.022       0.46600
# Sezen Aksu         0.395   0.327  110.352   -12.927       0.66100
# Sezen Aksu         0.769   0.621   93.972    -8.958       0.04110
# Sezen Aksu         0.485   0.730  174.015    -7.960       0.41900
# Sezen Aksu         0.325   0.557   69.835    -8.974       0.85000
# Sezen Aksu         0.404   0.427  120.172    -9.561       0.65900
# Sezen Aksu         0.435   0.788   95.602    -2.735       0.39500
# Sezen Aksu         0.570   0.366  106.900    -8.898       0.82400
# Sezen Aksu         0.337   0.476  108.597    -8.282       0.86900
# Sezen Aksu         0.360   0.478  101.121    -6.313       0.85900
# Sezen Aksu         0.744   0.556  108.012    -8.997       0.24700
# Sezen Aksu         0.621   0.878  126.027    -7.567       0.09670
# Sezen Aksu         0.547   0.751   92.721    -7.578       0.28300
# Sezen Aksu         0.335   0.420  167.912   -14.126       0.64800
# Sezen Aksu         0.395   0.675  177.053    -5.881       0.64900
# Sezen Aksu         0.726   0.895  120.926    -6.064       0.65300
# Sezen Aksu         0.641   0.795  119.750    -6.605       0.60900
# Sezen Aksu         0.339   0.781   79.270    -5.469       0.65300
# Sezen Aksu         0.753   0.561  132.055    -6.856       0.31000
# Sezen Aksu         0.304   0.659  113.021    -6.091       0.02860
# Sezen Aksu         0.653   0.815   89.985    -5.755       0.05920
# Sezen Aksu         0.745   0.934  119.985    -6.570       0.00212
# Sezen Aksu         0.385   0.755  120.154    -5.931       0.48500
# Sezen Aksu         0.708   0.666  134.963    -6.599       0.46000
# Sezen Aksu         0.654   0.533  127.490    -9.426       0.53200
# Sezen Aksu         0.662   0.784   98.005    -5.193       0.11800
# Sezen Aksu         0.610   0.616  144.926    -5.789       0.58300
# Sezen Aksu         0.743   0.798   95.013    -6.383       0.11600
# Sezen Aksu         0.632   0.377  114.148    -7.148       0.83700
# Sezen Aksu         0.752   0.814  119.026    -6.787       0.03150
# Sezen Aksu         0.754   0.854  116.031    -6.326       0.72300
# Sezen Aksu         0.609   0.731  158.284    -6.495       0.45500
# Sezen Aksu         0.709   0.800   95.993    -6.198       0.28800
# Sezen Aksu         0.741   0.718   96.069    -6.429       0.56200
# Sezen Aksu         0.647   0.682  109.985    -7.036       0.47400
# Sezen Aksu         0.624   0.849   89.745    -8.060       0.10100

# %% [markdown]
# So we got it! "Gülümse" is the most heartbreaking song in terms of its musicality. Also this is one of my favorite poems but I won't go and translate probably I would screw :(.
#
# Vice versa "Ne Kavgam Bitti Ne Sevdam" is the most cheerful song. This might seem abit strange to people who know the song because still the lyric is not cheerful but Spotify things the musicality is.

# %% [markdown]
# For people who might be curious, let's sort them by other features as well.

# %% [markdown]
# Most danceable 5:

# %%
sezenDf.sort_values("danceability", ascending=False).iloc[:5]
# Out:
#                                                     name  happiness  \
# Sezen Aksu  Gelsin Hayat Bildiği Gibi (feat. Sezen Aksu)      0.400
# Sezen Aksu                                        Rakkas      0.767
# Sezen Aksu                                       Tutuklu      0.537
# Sezen Aksu                                   Seni Yerler      0.762
# Sezen Aksu                               Aşktan Ne Haber      0.629
#
#             danceability  energy    tempo  loudness  acousticness
# Sezen Aksu         0.769   0.621   93.972    -8.958       0.04110
# Sezen Aksu         0.754   0.854  116.031    -6.326       0.72300
# Sezen Aksu         0.753   0.561  132.055    -6.856       0.31000
# Sezen Aksu         0.752   0.814  119.026    -6.787       0.03150
# Sezen Aksu         0.745   0.934  119.985    -6.570       0.00212

# %% [markdown]
# Most energic 5:

# %%
sezenDf.sort_values("energy", ascending=False).iloc[:5]
# Out:
#                                  name  happiness  danceability  energy  \
# Sezen Aksu            Aşktan Ne Haber      0.629         0.745   0.934
# Sezen Aksu             Seni İstiyorum      0.504         0.726   0.895
# Sezen Aksu               Canımsın Sen      0.477         0.621   0.878
# Sezen Aksu                     Rakkas      0.767         0.754   0.854
# Sezen Aksu  Ne Kavgam Bitti Ne Sevdam      0.955         0.624   0.849
#
#               tempo  loudness  acousticness
# Sezen Aksu  119.985    -6.570       0.00212
# Sezen Aksu  120.926    -6.064       0.65300
# Sezen Aksu  126.027    -7.567       0.09670
# Sezen Aksu  116.031    -6.326       0.72300
# Sezen Aksu   89.745    -8.060       0.10100

# %% [markdown]
# Just for fun I will create a couple of nice plots to compare those features. (Sorry for alot of plots, I know how to make things nicer but I need money for deployment :(  )

# %% [markdown]
# Let's see a scatter plot showing the distribution of danceability and happiness

# %%
from bokeh.io import curdoc,show, output_notebook
from bokeh.models import ColumnDataSource,HoverTool
from bokeh.plotting import figure
output_notebook()

# Make the ColumnDataSource: source
data = sezenDf

source = ColumnDataSource(data={
    'x'       : data.loc[my_artist].happiness,
    'y'       : data.loc[my_artist].danceability,
    'name'    : data.loc[my_artist].name
})

# Save the minimum and maximum values of the fertility column: xmin, xmax
xmin, xmax = min(data.loc[my_artist].happiness), max(data.loc[my_artist].happiness)

# Save the minimum and maximum values of the life expectancy column: ymin, ymax
ymin, ymax = min(data.loc[my_artist].danceability), max(data.loc[my_artist].danceability)

# Create the figure: plot
plot = figure(title='Most popular 50 songs by {0}'.format(my_artist), plot_height=400, plot_width=700,
              x_range=(xmin, xmax), y_range=(ymin, ymax))

# Add circle glyphs to the plot
plot.circle(x='x', y='y', fill_alpha=0.8, source=source)

# Set the x-axis label
plot.xaxis.axis_label ='Happiness'

# Set the y-axis label
plot.yaxis.axis_label = 'Danceability'

# Create a HoverTool: hover
hover = HoverTool(tooltips = [('Name', '@name')])
# Add the HoverTool to the plot
plot.add_tools(hover)
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3b6aad3d-3bf1-4e14-83cf-ba3e5f5d88db">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="bcf82ed0-a076-43a3-805c-f36c70afa96c"></div>
# </div>

# %%
def update(new_x,new_y):
    new_data = {
    'x'       : data.loc[my_artist][new_x],
    'y'       : data.loc[my_artist][new_y],
    'name'    : data.loc[my_artist].name
    }
    source.data = new_data
    # Save the minimum and maximum values of the fertility column: xmin, xmax
    xmin, xmax = min(data.loc[my_artist][new_x]), max(data.loc[my_artist][new_x])
    # Save the minimum and maximum values of the life expectancy column: ymin, ymax
    ymin, ymax = min(data.loc[my_artist][new_y]), max(data.loc[my_artist][new_y])
     # Set the range of all axes
    plot.x_range.start = xmin
    plot.x_range.end = xmax
    plot.y_range.start = ymin
    plot.y_range.end = ymax
    
    # Set the x-axis label
    plot.xaxis.axis_label =new_x

    # Set the y-axis label
    plot.yaxis.axis_label = new_y
    show(plot)

# %% [markdown]
# And now loudness versus happiness

# %%
update('loudness', 'happiness')
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="8568f215-ca0d-4052-a214-2e758c2fa51c"></div>
# </div>

# %% [markdown]
# Finally just out of my curiosity, I wanna see 5 happiest and 5 saddest song of some artists bumped in my head :)

# %%
from IPython.display import display, HTML
my_artists = ['Michael Jackson', 'Imagine Dragons', 'Frank Sinatra', 'Pink Martini', 'Stromae', 'Bülent Ortaçgil','Teoman']

# %% [markdown]
# Most heartbreaking 5

# %%
for artist in my_artists:
    display(getSongsDf(artist).drop_duplicates('name').sort_values('happiness').iloc[:5])
# Out:
#                                                       name  happiness  \
# Michael Jackson                             Heal the World      0.102
# Michael Jackson  Don’t Matter To Me (with Michael Jackson)      0.138
# Michael Jackson                          You Are Not Alone      0.256
# Michael Jackson                          Man in the Mirror      0.265
# Michael Jackson          Man in the Mirror - 2012 Remaster      0.269
#
#                  danceability  energy    tempo  loudness  acousticness
# Michael Jackson         0.534   0.485   80.923    -8.045         0.537
# Michael Jackson         0.826   0.318  103.002   -12.391         0.493
# Michael Jackson         0.651   0.402  119.878    -9.303         0.639
# Michael Jackson         0.794   0.798  100.338    -5.639         0.430
# Michael Jackson         0.808   0.812  100.331    -5.012         0.520
#                              name  happiness  danceability  energy    tempo  \
# Imagine Dragons        Battle Cry     0.0419         0.358   0.909  129.945
# Imagine Dragons         Not Today     0.0530         0.463   0.386  123.495
# Imagine Dragons  I Don’t Know Why     0.0725         0.639   0.641  120.927
# Imagine Dragons           Rise Up     0.1020         0.447   0.740   93.759
# Imagine Dragons             Dream     0.1150         0.346   0.509  143.437
#
#                  loudness  acousticness
# Imagine Dragons    -6.856        0.0429
# Imagine Dragons    -7.261        0.5650
# Imagine Dragons    -7.423        0.0066
# Imagine Dragons    -6.607        0.0122
# Imagine Dragons    -7.693        0.6740
#                                                             name  happiness  \
# Frank Sinatra  In The Wee Small Hours Of The Morning - Remast...     0.0734
# Frank Sinatra                           Someone to Watch Over Me     0.1340
# Frank Sinatra  If You Are But A Dream (with The Bobby Tucker ...     0.1380
# Frank Sinatra                            It Was A Very Good Year     0.1440
# Frank Sinatra                   The First Noel - Remastered 1999     0.1570
#
#                danceability  energy    tempo  loudness  acousticness
# Frank Sinatra         0.290  0.0874  114.997   -16.119         0.856
# Frank Sinatra         0.204  0.1510   91.783   -17.842         0.947
# Frank Sinatra         0.209  0.2260   86.775   -15.961         0.919
# Frank Sinatra         0.205  0.1410   88.043   -15.339         0.861
# Frank Sinatra         0.176  0.1530   84.741   -15.969         0.956
#                                name  happiness  danceability  energy    tempo  \
# Pink Martini                 Exodus      0.127         0.249  0.3030   81.734
# Pink Martini  Splendor in the Grass      0.142         0.400  0.2850   74.107
# Pink Martini    Children of Piraeus      0.152         0.462  0.0619   75.839
# Pink Martini   Dream a Little Dream      0.155         0.603  0.1640   98.501
# Pink Martini         Ov Sirun Sirun      0.159         0.365  0.2250  142.098
#
#               loudness  acousticness
# Pink Martini    -9.626         0.597
# Pink Martini    -7.565         0.778
# Pink Martini   -23.549         0.711
# Pink Martini   -13.504         0.968
# Pink Martini   -13.910         0.966
#                                     name  happiness  danceability  energy  \
# Stromae                          Silence     0.0369         0.589   0.548
# Stromae  House'llelujah - Shameboy Remix     0.1230         0.557   0.817
# Stromae                Repetto X Mosaert     0.2090         0.730   0.493
# Stromae          papaoutai - Bonus track     0.2270         0.750   0.777
# Stromae                    quand c'est ?     0.2410         0.405   0.373
#
#            tempo  loudness  acousticness
# Stromae  125.056   -12.013        0.0589
# Stromae  127.884    -8.752        0.0159
# Stromae  112.508    -9.234        0.2040
# Stromae  115.951    -7.920        0.1300
# Stromae  100.285   -12.539        0.0913
#                                  name  happiness  danceability  energy  \
# Bülent Ortaçgil  Benimle Oynar Mısın?      0.180         0.380  0.3020
# Bülent Ortaçgil          Eylül Akşamı      0.212         0.403  0.4190
# Bülent Ortaçgil                Yağmur      0.240         0.604  0.0985
# Bülent Ortaçgil    Benimle Oynarmısın      0.245         0.341  0.1200
# Bülent Ortaçgil         Bahar türküsü      0.249         0.576  0.1110
#
#                    tempo  loudness  acousticness
# Bülent Ortaçgil   78.239   -10.763         0.888
# Bülent Ortaçgil   81.455   -11.849         0.735
# Bülent Ortaçgil  100.638   -22.738         0.962
# Bülent Ortaçgil  184.517   -21.983         0.911
# Bülent Ortaçgil  104.753   -22.897         0.945
#                         name  happiness  danceability  energy    tempo  \
# Teoman                 Tuzak      0.095         0.282   0.225   52.293
# Teoman  İstanbul'da Sonbahar      0.161         0.486   0.145   84.162
# Teoman  Benimle Oynar Mısın?      0.180         0.380   0.302   78.239
# Teoman         Çoban Yıldızı      0.206         0.387   0.502  119.808
# Teoman          Eylül Akşamı      0.212         0.403   0.419   81.455
#
#         loudness  acousticness
# Teoman   -12.286         0.911
# Teoman   -16.369         0.913
# Teoman   -10.763         0.888
# Teoman    -6.062         0.433
# Teoman   -11.849         0.735

# %% [markdown]
# Happiest 5

# %%
for artist in my_artists:
    display(getSongsDf(artist).drop_duplicates('name').sort_values('happiness', ascending = False).iloc[:5])
# Out:
#                                                             name  happiness  \
# Michael Jackson                                    Rockin' Robin      0.968
# Michael Jackson                      P.Y.T. (Pretty Young Thing)      0.961
# Michael Jackson                  Black or White - Single Version      0.960
# Michael Jackson                                You Rock My World      0.955
# Michael Jackson  Don't Stop 'Til You Get Enough - Single Version      0.947
#
#                  danceability  energy    tempo  loudness  acousticness
# Michael Jackson         0.628   0.712  173.195    -8.191        0.2450
# Michael Jackson         0.888   0.815  127.273    -4.909        0.2300
# Michael Jackson         0.741   0.894  114.869    -3.826        0.0824
# Michael Jackson         0.854   0.673   95.000    -3.132        0.0380
# Michael Jackson         0.878   0.821  118.881    -9.875        0.1260
#                                                               name  happiness  \
# Imagine Dragons                                          It's Time      0.860
# Imagine Dragons                                On Top Of The World      0.761
# Imagine Dragons                                         Start Over      0.757
# Imagine Dragons  Sucker For Pain (with Wiz Khalifa, Imagine Dra...      0.739
# Imagine Dragons                                           Believer      0.666
#
#                  danceability  energy    tempo  loudness  acousticness
# Imagine Dragons         0.656   0.884  105.009    -4.748       0.01620
# Imagine Dragons         0.635   0.926  100.048    -5.589       0.08930
# Imagine Dragons         0.698   0.928   98.040    -5.051       0.00551
# Imagine Dragons         0.502   0.786  169.021    -4.378       0.25500
# Imagine Dragons         0.776   0.780  124.949    -4.374       0.06220
#                                                             name  happiness  \
# Frank Sinatra  Let It Snow! Let It Snow! Let It Snow! (with T...      0.844
# Frank Sinatra                            I Get A Kick Out Of You      0.775
# Frank Sinatra                  Blue Moon - 1998 Digital Remaster      0.744
# Frank Sinatra  When You're Smiling (The Whole World Smiles Wi...      0.702
# Frank Sinatra                   The Lady Is A Tramp - Remastered      0.645
#
#                danceability  energy    tempo  loudness  acousticness
# Frank Sinatra         0.603   0.321  143.104   -11.489         0.881
# Frank Sinatra         0.395   0.375  178.105   -10.966         0.555
# Frank Sinatra         0.644   0.156  113.960   -16.529         0.532
# Frank Sinatra         0.565   0.329   79.054   -12.222         0.436
# Frank Sinatra         0.587   0.150  129.745   -13.877         0.499
#                                 name  happiness  danceability  energy  \
# Pink Martini  ¿Donde Estas, Yolanda?      0.967         0.845   0.557
# Pink Martini   Donde Estas, Yolanda?      0.967         0.831   0.618
# Pink Martini                 Zundoko      0.902         0.710   0.642
# Pink Martini         No Hay Problema      0.897         0.821   0.585
# Pink Martini                   Lilly      0.878         0.753   0.504
#
#                 tempo  loudness  acousticness
# Pink Martini  143.297   -10.872         0.617
# Pink Martini  143.213    -9.183         0.693
# Pink Martini  120.774    -6.030         0.341
# Pink Martini  130.595   -12.529         0.812
# Pink Martini  146.857    -8.939         0.655
#                            name  happiness  danceability  energy    tempo  \
# Stromae               Te Quiero      0.848         0.610   0.692  122.950
# Stromae                     avf      0.813         0.844   0.697  137.003
# Stromae                Je Cours      0.805         0.831   0.608  120.986
# Stromae                  bâtard      0.792         0.745   0.746  126.000
# Stromae  Tous Les Mêmes - Remix      0.777         0.692   0.643  110.055
#
#          loudness  acousticness
# Stromae    -8.644       0.13900
# Stromae    -8.057       0.00366
# Stromae    -9.126       0.38800
# Stromae    -9.582       0.04370
# Stromae    -8.085       0.00401
#                                  name  happiness  danceability  energy  \
# Bülent Ortaçgil  Beni Kategorize Etme      0.922         0.766   0.663
# Bülent Ortaçgil      Buş İç Zor Yonca      0.853         0.728   0.611
# Bülent Ortaçgil          Denize Doğru      0.730         0.520   0.498
# Bülent Ortaçgil    Pencere Önü Çiçeği      0.659         0.758   0.401
# Bülent Ortaçgil                Adalar      0.659         0.436   0.549
#
#                    tempo  loudness  acousticness
# Bülent Ortaçgil   91.314    -9.403         0.599
# Bülent Ortaçgil  130.673    -8.396         0.802
# Bülent Ortaçgil   84.827    -9.285         0.363
# Bülent Ortaçgil  128.678    -9.977         0.825
# Bülent Ortaçgil  145.426    -8.540         0.742
#                                           name  happiness  danceability  \
# Teoman  Bu Aşk Fazla Sana - Mahmut Orhan Remix      0.955         0.745
# Teoman                                 Papatya      0.904         0.636
# Teoman                    Yıldızları Yakalamak      0.880         0.582
# Teoman                              Saat 03:00      0.828         0.546
# Teoman                   Terlemeden Sevişenler      0.806         0.486
#
#         energy    tempo  loudness  acousticness
# Teoman   0.822  125.000    -6.920       0.00355
# Teoman   0.817   80.403    -9.440       0.05650
# Teoman   0.938  150.015    -5.951       0.02960
# Teoman   0.880  147.710    -5.588       0.07050
# Teoman   0.885  174.029    -4.136       0.02640

# %% [markdown]
# I have fancier ideas with this thing, hope u enjoyed!
